# %%
# %matplotlib inline
import math
import random
import numpy as np
import pickle
import matplotlib.pyplot as plt
import scipy.io as sio

# %%
record_name = '_moving2'
file_load1 = open('./HCWS/Record'+record_name+'.pkl', 'rb')
Record_load = pickle.load(file_load1)
Record = np.asarray(Record_load[::1])
reward = Record[:,0]
w = Record[:,2]
maxw = Record[:,3]
loss = Record[:,4]

x = np.arange(0, len(Record), 1)
plt.figure(0)
plt.plot(x, reward)
plt.title("reward")

file_load = open('./HCWS/Evaluation'+record_name+'.pkl', 'rb')
Eva_load = pickle.load(file_load)
Eva = np.asarray(Eva_load[::1])
w_eva = Eva[:,0]
maxw_eva = Eva[:,1]

x_eva = np.arange(0, len(Eva), 1)

plt.figure(12)
plt.plot(x_eva, maxw_eva)
plt.title("maxw_eva")

# %%
file_load1 = open('./HCWS/Record_writhe3.pkl', 'rb')
Record_load1 = pickle.load(file_load1)
Record1 = np.asarray(Record_load1[::1])
r1 = Record1[:,0]
w1 = Record1[:,2]
maxw1 = Record1[:,3]
loss1 = Record1[:,4]

file_load2 = open('./HCWS/Record_writhe4.pkl', 'rb')
Record_load2 = pickle.load(file_load2)
Record2 = np.asarray(Record_load2[::1])
r2 = Record2[:,0]
w2 = Record2[:,2]
maxw2 = Record2[:,3]
loss2 = Record2[:,4]

file_load3 = open('./HCWS/Record_writhe5.pkl', 'rb')
Record_load3 = pickle.load(file_load3)
Record3 = np.asarray(Record_load3[::1])
r3 = Record3[:,0]
w3 = Record3[:,2]
maxw3 = Record3[:,3]
loss3 = Record3[:,4]

file_load4 = open('./SKY/Record_writhe1.pkl', 'rb')
Record_load4 = pickle.load(file_load4)
Record4 = np.asarray(Record_load4[::1])
r4 = Record4[:,0]
w4 = Record4[:,2]
maxw4 = Record4[:,3]
loss4 = Record4[:,4]

file_load5 = open('./SKY/Record_writhe2.pkl', 'rb')
Record_load5 = pickle.load(file_load5)
Record5 = np.asarray(Record_load5[::1])
r5 = Record5[:,0]
w5 = Record5[:,2]
maxw5 = Record5[:,3]
loss5 = Record5[:,4]

file_load6 = open('./SKY/Record_writhe3.pkl', 'rb')
Record_load6 = pickle.load(file_load6)
Record6 = np.asarray(Record_load6[::1])
r6 = Record6[:,0]
w6 = Record6[:,2]
maxw6 = Record6[:,3]
loss6 = Record6[:,4]

x = np.arange(0, len(Record1), 1)
sio.savemat('record_writhe.mat', 
            {'x':x,
             'r1':r1, 'r2':r2, 'r3':r3, 'r4':r4, 'r5':r5, 'r6':r6,
             'loss1':loss1, 'loss2':loss2, 'loss3':loss3, 'loss4':loss4, 'loss5':loss5, 'loss6':loss6,
             'w1':w1, 'w2':w2, 'w3':w3, 'w4':w4, 'w5':w5, 'w6':w6,
             'maxw1':maxw1, 'maxw2':maxw2, 'maxw3':maxw3, 'maxw4':maxw4, 'maxw5':maxw5, 'maxw6':maxw6})

# %%
x = np.arange(0, len(Record1), 1)

f0 = plt.figure(0)
p1, = plt.plot(x, w1)
p2, = plt.plot(x, w2)
p3, = plt.plot(x, w3)
p4, = plt.plot(x, w4)
p5, = plt.plot(x, w5)
p6, = plt.plot(x, w6)
plt.title("w")

plt.legend([p1,p2,p3,p4,p5,p6], loc='best',title='figure 1 legend') 

plt.figure(1)
plt.plot(x, maxw1)
plt.plot(x, maxw2)
plt.plot(x, maxw3)
plt.plot(x, maxw4)
plt.plot(x, maxw5)
plt.plot(x, maxw6)
plt.title("maxw")

# sio.savemat('record_intermesh.mat', 
#             {'x':x,
#              'w1':w1, 'w2':w2, 'w3':w3,
#              'maxw1':maxw1, 'maxw2':maxw2, 'maxw3':maxw3})

sio.savemat('record_writhe.mat', 
            {'x':x,
             'w1':w1, 'w2':w2, 'w3':w3, 'w4':w4, 'w5':w5, 'w6':w6,
             'maxw1':maxw1, 'maxw2':maxw2, 'maxw3':maxw3, 'maxw4':maxw4, 'maxw5':maxw5, 'maxw6':maxw6})

# %%
file_load1 = open('./HCWS/Evaluation_writhe3.pkl', 'rb')
Record_load1 = pickle.load(file_load1)
Record1 = np.asarray(Record_load1[::1])
w1 = Record1[:,0]
maxw1 = Record1[:,1]

file_load2 = open('./HCWS/Evaluation_writhe4.pkl', 'rb')
Record_load2 = pickle.load(file_load2)
Record2 = np.asarray(Record_load2[::1])
w2 = Record2[:,0]
maxw2 = Record2[:,1]

file_load3 = open('./HCWS/Evaluation_writhe5.pkl', 'rb')
Record_load3 = pickle.load(file_load3)
Record3 = np.asarray(Record_load3[::1])
w3 = Record3[:,0]
maxw3 = Record3[:,1]

file_load4 = open('./SKY/Evaluation_writhe1.pkl', 'rb')
Record_load4 = pickle.load(file_load4)
Record4 = np.asarray(Record_load4[::1])
w4 = Record4[:,0]
maxw4 = Record4[:,1]

file_load5 = open('./SKY/Evaluation_writhe2.pkl', 'rb')
Record_load5 = pickle.load(file_load5)
Record5 = np.asarray(Record_load5[::1])
w5 = Record5[:,0]
maxw5 = Record5[:,1]

file_load6 = open('./HCWS/Evaluation_writhe3.pkl', 'rb')
Record_load6 = pickle.load(file_load6)
Record6 = np.asarray(Record_load6[::1])
w6 = Record6[:,0]
maxw6 = Record6[:,1]

# %%
x = np.arange(0, len(Record1), 1)

plt.figure(11)
plt.plot(x, w1)
plt.plot(x, w2)
plt.plot(x, w3)
plt.plot(x, w4)
plt.plot(x, w5)
plt.plot(x, w6)
plt.title("w")

plt.figure(12)
plt.plot(x, maxw1)
plt.plot(x, maxw2)
plt.plot(x, maxw3)
plt.plot(x, maxw4)
plt.plot(x, maxw5)
plt.plot(x, maxw6)
plt.title("maxw")

# sio.savemat('evalu_intermesh.mat', 
#             {'x':x,
#              'w1':w1, 'w2':w2, 'w3':w3,
#              'maxw1':maxw1, 'maxw2':maxw2, 'maxw3':maxw3})

sio.savemat('evalu_writhe.mat', 
            {'x':x,
             'w1':w1, 'w2':w2, 'w3':w3, 'w4':w4, 'w5':w5, 'w6':w6,
             'maxw1':maxw1, 'maxw2':maxw2, 'maxw3':maxw3, 'maxw4':maxw4, 'maxw5':maxw5, 'maxw6':maxw6})

# %%
# generate writhe+intermesh data for matlab
file_load1 = open('./SKY/Record1.pkl', 'rb')
Record_load1 = pickle.load(file_load1)
Record1 = np.asarray(Record_load1[::1])
r1 = Record1[:,0]
w1 = Record1[:,2]
maxw1 = Record1[:,3]
loss1 = Record1[:,4]

file_load2 = open('./SKY/Record4.pkl', 'rb')
Record_load2 = pickle.load(file_load2)
Record2 = np.asarray(Record_load2[::1])
r2 = Record2[:,0]
w2 = Record2[:,2]
maxw2 = Record2[:,3]
loss2 = Record2[:,4]

file_load3 = open('./SKY/Record5.pkl', 'rb')
Record_load3 = pickle.load(file_load3)
Record3 = np.asarray(Record_load3[::1])
r3 = Record3[:,0]
w3 = Record3[:,2]
maxw3 = Record3[:,3]
loss3 = Record3[:,4]

file_load4 = open('./SKY/Record7.pkl', 'rb')
Record_load4 = pickle.load(file_load4)
Record4 = np.asarray(Record_load4[::1])
r4 = Record4[:,0]
w4 = Record4[:,2]
maxw4 = Record4[:,3]
loss4 = Record4[:,4]

file_load5 = open('./SKY/Record8.pkl', 'rb')
Record_load5 = pickle.load(file_load5)
Record5 = np.asarray(Record_load5[::1])
r5 = Record5[:,0]
w5 = Record5[:,2]
maxw5 = Record5[:,3]
loss5 = Record5[:,4]

file_load6 = open('./HCWS/Record_moving2.pkl', 'rb')
Record_load6 = pickle.load(file_load6)
Record6 = np.asarray(Record_load6[::1])
r6 = Record6[:,0]
w6 = Record6[:,2]
maxw6 = Record6[:,3]
loss6 = Record6[:,4]

x = np.arange(0, len(Record1), 1)
sio.savemat('record_writheinter.mat', 
            {'x':x,
             'r1':r1, 'r2':r2, 'r3':r3, 'r4':r4, 'r5':r5, 'r6':r6,
             'loss1':loss1, 'loss2':loss2, 'loss3':loss3, 'loss4':loss4, 'loss5':loss5, 'loss6':loss6,
             'w1':w1, 'w2':w2, 'w3':w3, 'w4':w4, 'w5':w5, 'w6':w6,
             'maxw1':maxw1, 'maxw2':maxw2, 'maxw3':maxw3, 'maxw4':maxw4, 'maxw5':maxw5, 'maxw6':maxw6})

# %%
# generate intermesh data for matlab
file_load1 = open('./HCWS/Record_intermesh2.pkl', 'rb')
Record_load1 = pickle.load(file_load1)
Record1 = np.asarray(Record_load1[::1])
r1 = Record1[:,0]
w1 = Record1[:,2]
maxw1 = Record1[:,3]
loss1 = Record1[:,4]

file_load2 = open('./HCWS/Record_intermesh3.pkl', 'rb')
Record_load2 = pickle.load(file_load2)
Record2 = np.asarray(Record_load2[::1])
r2 = Record2[:,0]
w2 = Record2[:,2]
maxw2 = Record2[:,3]
loss2 = Record2[:,4]

file_load3 = open('./HCWS/Record_intermesh21.pkl', 'rb')
Record_load3 = pickle.load(file_load3)
Record3 = np.asarray(Record_load3[::1])
r3 = Record3[:,0]
w3 = Record3[:,2]
maxw3 = Record3[:,3]
loss3 = Record3[:,4]


x = np.arange(0, len(Record1), 1)
sio.savemat('record_inter.mat', 
            {'x':x,
             'r1':r1, 'r2':r2, 'r3':r3, 
             'loss1':loss1, 'loss2':loss2, 'loss3':loss3, 
             'w1':w1, 'w2':w2, 'w3':w3, 
             'maxw1':maxw1, 'maxw2':maxw2, 'maxw3':maxw3})
